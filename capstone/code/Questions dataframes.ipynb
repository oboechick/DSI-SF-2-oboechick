# %%
import pandas as pd
import numpy as np
import seaborn as sns

from matplotlib import pyplot as ppt

# %%
student_survey_dict = pd.read_csv('/Users/nichollejames/Desktop/capstone_project/dictionaries/students_dict.csv')

# %%
student_survey_dict.tail(315)
# Out:
#            Code                                              Label
# 300     IC02Q07                           At school - Ebook reader
# 301     IC03Q01                             First use of computers
# 302     IC04Q01                           First access to Internet
# 303     IC05Q01                                 Internet at School
# 304     IC06Q01                   Internet out-of-school - Weekday
# 305     IC07Q01                   Internet out-of-school - Weekend
# 306     IC08Q01                Out-of-school 8 - One player games.
# 307     IC08Q02           Out-of-school 8 - ColLabourative games.
# 308     IC08Q03                        Out-of-school 8 - Use email
# 309     IC08Q04                     Out-of-school 8 - Chat on line
# 310     IC08Q05                  Out-of-school 8 - Social networks
# 311     IC08Q06      Out-of-school 8 - Browse the Internet for fun
# 312     IC08Q07                        Out-of-school 8 - Read news
# ...

# %%
parent_survery_dict = pd.read_csv('/Users/nichollejames/Desktop/capstone_project/dictionaries/parent_dict.cvs')

# %%
parent_survery_dict.head(10)
# Out:
#                                             variable labels
# NC                             National Centre 6-digit Code
# CNT                                Country code 3-character
# OECD                                           OECD country
# SUBNATIO  Adjudicated sub-region code 7-digit code (3-di...
# STRATUM   Stratum ID 7-character (cnt + region ID + orig...
# SCHOOLID  School ID 7-digit (region ID + stratum ID + 3-...
# STIDSTD                                          Student ID
# PA01Q01                              Completed Quest-Mother
# PA01Q02                              Completed Quest-Father
# PA01Q03                               Completed Quest-Other

# %%
school_survey_dict = pd.read_csv('/Users/nichollejames/Desktop/capstone_project/dictionaries/school_dict.csv')

# %%
school_survey_dict.head(10)
# Out:
#    variable                                             labels
# 0        NC                       National Centre 6-digit Code
# 1       CNT                           Country code 3-character
# 2      OECD                                       OECD country
# 3  SUBNATIO  Adjudicated sub-region code 7-digit code (3-di...
# 4   STRATUM  Stratum ID 7-character (cnt + region ID + orig...
# 5  SCHOOLID  School ID 7-digit (region ID + stratum ID + 3-...
# 6   SC01Q01                                  Public or private
# 7   SC02Q01                               Funding - Government
# 8   SC02Q02                             Funding - Student fees
# 9   SC02Q03                              Funding - Benefactors

# %%
CBA_cog_dict = pd.read_csv('/Users/nichollejames/Desktop/capstone_project/dictionaries/CBA_cog_dict.csv')

# %%
CBA_cog_scored_dict = pd.read_csv('/Users/nichollejames/Desktop/capstone_project/dictionaries/CBA_scored_cog_dict.csv')
