# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 15px; height: 80px">
#
# # Project 7
#
# ## NLP and Machine Learning on [travel.statsexchange.com](http://travel.stackexchange.com/) data
#
# ---
#
# In Project 7 you'll be doing NLP and machine learning on post data from stackexchange's travel subdomain.
#
# This project is setup like a mini Kaggle competition. You are given the training data and when projects are submitted your model will be tested on the held-out testing data. There will be prizes for the people who build models that perform best on the held out test set!
#
# ---
#
# ## Notes on the data
#
# The data is again compressed into the `.7z` file format to save space. There are 6 .csv files and one readme file that contains some information on the fields.
#
#     posts_train.csv
#     comments_train.csv
#     users.csv
#     badges.csv
#     votes_train.csv
#     tags.csv
#     readme.txt
#
# The data is located in your datasets folder:
#
#     DSI-SF-2/datasets/stack_exchange_travel.7z
#
# If you're interested in where this data came from and where to get more data from other stackexchange subdomains, see here:
#
# https://ia800500.us.archive.org/22/items/stackexchange/readme.txt
#
#
# ### Recommended Utilities for .7z
#
# - For OSX [Keka](http://www.kekaosx.com/en/) or [The Unarchiver](http://wakaba.c3.cx/s/apps/unarchiver.html).
# - For Windows [7-zip](http://www.7-zip.org/) is the standard.
# - For Linux try the `p7zip` utility.  `sudo apt-get install p7zip`.

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 1. Use LDA to find what topics are discussed on travel.stackexchange.com.
#
# ---
#
# Text can be found in the posts and the comments datasets. The `ParentId` column in the posts dataset indicates what the "question" post was for a given post. Comment text can be merged onto the post they are part of with the `PostId` field.
#
# The text may have some HTML tags. BeautifulSoup has convenient ways to get rid of markup or extract text if you need to. You can also parse the strings yourself if you like.
#
# The tags dataset has the "tags" that the users have officially given the post.
#
# **1.1 Implement LDA against the text features of the dataset(s).**
#
# - This can be posts or a combination of posts and comments if you want more power.
# - Find optimal **K/num_topics**.
#
# **1.2 Compare your topics to the tags. Do the LDA topics make sense? How do they compare to the tags?**

# %%
from gensim import corpora, models, matutils
from sklearn.feature_extraction.text import CountVectorizer
from collections import defaultdict
import pandas as pd

# %%
badges = pd.read_csv('/Users/nichollejames/Desktop/DSI-SF-2-oboechick/projects/project-07/stack_exchange_travel/badges.csv')
comments_train = pd.read_csv('/Users/nichollejames/Desktop/DSI-SF-2-oboechick/projects/project-07/stack_exchange_travel/comments_train.csv')
posts_train = pd.read_csv('/Users/nichollejames/Desktop/DSI-SF-2-oboechick/projects/project-07/stack_exchange_travel/posts_train.csv')
tags = pd.read_csv('/Users/nichollejames/Desktop/DSI-SF-2-oboechick/projects/project-07/stack_exchange_travel/tags.csv')
users = pd.read_csv('/Users/nichollejames/Desktop/DSI-SF-2-oboechick/projects/project-07/stack_exchange_travel/users.csv')
votes_train = pd.read_csv('/Users/nichollejames/Desktop/DSI-SF-2-oboechick/projects/project-07/stack_exchange_travel/votes_train.csv')

# %%
# save/load the model so this doesn't need to be run every time...
import cPickle
f = open('/Users/nichollejames/llejames/chollejames/chollejames/Desktop/DSI-SF-2-oboechick/projects/project-07/project-7.p','w')  # w = write, r = read
cPickle.dump(gb_cv,f)
f.close()
f = open('/Users/nichollejames/Desktop/DSI-SF-2-oboechick/projects/project-07/project-7.p','r')
gb_cv = cPickle.load(f)
f.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-61693db856cc> in <module>()
#       2 import cPickle
#       3 f = open('/Users/nichollejames/Desktop/DSI-SF-2-oboechick/projects/project-07/project-7.p','w')  # w = write, r = read
# ----> 4 cPickle.dump(gb_cv,f)
#       5 f.close()
#       6 f = open('/Users/nichollejames/Desktop/DSI-SF-2-oboechick/projects/project-07/project-7.p','r')
#
# NameError: name 'gb_cv' is not defined

# %% [markdown]
# ## posts_train

# %%
posts_train.head()
# Out:
#    AcceptedAnswerId  AnswerCount  \
# 0             393.0          4.0
# 1               NaN          1.0
# 2             770.0          5.0
# 3              62.0          3.0
# 4             178.0          4.0
#
#                                                 Body               ClosedDate  \
# 0  <p>My fiancée and I are looking for a good Car...  2013-02-25T23:52:47.953
# 1  <p>Singapore Airlines has an all-business clas...                      NaN
# 2  <p>Another definition question that interested...                      NaN
# 3  <p>Can anyone suggest the best way to get from...                      NaN
# 4  <p>We are considering visiting Argentina for u...  2016-01-02T10:26:48.277
#
#    CommentCount CommunityOwnedDate             CreationDate  FavoriteCount  \
# 0             4                NaN  2011-06-21T20:19:34.730            NaN
# 1             1                NaN  2011-06-21T20:24:57.160            NaN
# 2             0                NaN  2011-06-21T20:25:56.787            2.0
# 3             2                NaN  2011-06-21T20:30:38.687            1.0
# 4             1                NaN  2011-06-21T20:31:21.800            8.0
#
#    Id         LastActivityDate    ...    LastEditorDisplayName  \
# 0   1  2012-05-24T14:52:14.760    ...                      NaN
# 1   4  2013-01-09T09:55:22.743    ...                      NaN
# 2   5  2012-10-12T20:49:08.110    ...                      NaN
# 3   8  2016-03-28T03:41:28.130    ...                  user141
# 4   9  2016-01-01T21:58:02.303    ...                      NaN
#
#   LastEditorUserId  OwnerDisplayName OwnerUserId  ParentId  PostTypeId  Score  \
# 0            101.0               NaN         9.0       NaN           1      8
# 1            693.0               NaN        24.0       NaN           1      8
# 2            101.0               NaN        13.0       NaN           1     11
# 3              NaN               NaN        26.0       NaN           1     11
# 4            101.0               NaN        23.0       NaN           1     12
#
#                                                 Tags  \
# 0                   <caribbean><cruising><vacations>
# 1  <loyalty-programs><routes><ewr><singapore-airl...
# 2                          <romania><transportation>
# 3            <usa><airport-transfer><taxis><seattle>
# 4  <sightseeing><public-transport><transportation...
#
#                                                Title ViewCount
# 0       What are some Caribbean cruises for October?     361.0
# 1  Does Singapore Airlines offer any reward seats...     219.0
# 2  What is the easiest transportation to use thro...     340.0
# 3    Best way to get from SeaTac airport to Redmond?    9219.0
# 4  What are must-visit destinations for the first...    1503.0
#
# [5 rows x 21 columns]

# %%
posts_train.isnull().sum()

posts_train.dropna(inplace=True)

# %%
posts_train.isnull().sum()
# Out:
# AcceptedAnswerId         0.0
# AnswerCount              0.0
# Body                     0.0
# ClosedDate               0.0
# CommentCount             0.0
# CommunityOwnedDate       0.0
# CreationDate             0.0
# FavoriteCount            0.0
# Id                       0.0
# LastActivityDate         0.0
# LastEditDate             0.0
# LastEditorDisplayName    0.0
# LastEditorUserId         0.0
# OwnerDisplayName         0.0
# OwnerUserId              0.0
# ParentId                 0.0
# PostTypeId               0.0
# Score                    0.0
# Tags                     0.0
# Title                    0.0
# ViewCount                0.0
# dtype: float64

# %%
# Take Text column and set up so LDA is possible
vectorizer = CountVectorizer(stop_words='english')
X = vectorizer.fit_transform(posts_train.Body.values)

vectorizer.vocabulary_

docs = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-322b2a3663d3> in <module>()
#       1 # Take Text column and set up so LDA is possible
#       2 vectorizer = CountVectorizer(stop_words='english')
# ----> 3 X = vectorizer.fit_transform(posts_train.Body.values)
#       4
#       5 vectorizer.vocabulary_
#
# /Users/nichollejames/anaconda/envs/dsi/lib/python2.7/site-packages/sklearn/feature_extraction/text.pyc in fit_transform(self, raw_documents, y)
#     815
#     816         vocabulary, X = self._count_vocab(raw_documents,
# --> 817                                           self.fixed_vocabulary_)
#     818
#     819         if self.binary:
#
# /Users/nichollejames/anaconda/envs/dsi/lib/python2.7/site-packages/sklearn/feature_extraction/text.pyc in _count_vocab(self, raw_documents, fixed_vocab)
#     762             vocabulary = dict(vocabulary)
#     763             if not vocabulary:
# --> 764                 raise ValueError("empty vocabulary; perhaps the documents only"
#     765                                  " contain stop words")
#     766
#
# ValueError: empty vocabulary; perhaps the documents only contain stop words

# %%
# Take Text column and set up so LDA is possible
vectorizer = CountVectorizer(stop_words='english')
X = vectorizer.fit_transform(posts_train.Tags.values)

vectorizer.vocabulary_

docs = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-2f794debe0a3> in <module>()
#       1 # Take Text column and set up so LDA is possible
#       2 vectorizer = CountVectorizer(stop_words='english')
# ----> 3 X = vectorizer.fit_transform(posts_train.Tags.values)
#       4
#       5 vectorizer.vocabulary_
#
# /Users/nichollejames/anaconda/envs/dsi/lib/python2.7/site-packages/sklearn/feature_extraction/text.pyc in fit_transform(self, raw_documents, y)
#     815
#     816         vocabulary, X = self._count_vocab(raw_documents,
# --> 817                                           self.fixed_vocabulary_)
#     818
#     819         if self.binary:
#
# /Users/nichollejames/anaconda/envs/dsi/lib/python2.7/site-packages/sklearn/feature_extraction/text.pyc in _count_vocab(self, raw_documents, fixed_vocab)
#     762             vocabulary = dict(vocabulary)
#     763             if not vocabulary:
# --> 764                 raise ValueError("empty vocabulary; perhaps the documents only"
#     765                                  " contain stop words")
#     766
#
# ValueError: empty vocabulary; perhaps the documents only contain stop words

# %%
# Take Text column and set up so LDA is possible
vectorizer = CountVectorizer(stop_words='english')
X = vectorizer.fit_transform(posts_train.Title.values)

vectorizer.vocabulary_

docs = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names())

# %% [markdown]
# ## tags

# %%
# Take Text column and set up so LDA is possible
vectorizer = CountVectorizer(stop_words='english')
X = vectorizer.fit_transform(tags.TagName.values)

vectorizer.vocabulary_

docs = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names())

# %%
# Swap a dictionary key / value order.  This is the format gensim LDA expects it's vocabulary.
vocab = {v: k for k, v in vectorizer.vocabulary_.iteritems()}

# %%
vectorizer
# Out:
# CountVectorizer(analyzer=u'word', binary=False, decode_error=u'strict',
#         dtype=<type 'numpy.int64'>, encoding=u'utf-8', input=u'content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words='english',
#         strip_accents=None, token_pattern=u'(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
# remove words that appear only once
frequency = defaultdict(int)

for text in docs:
    for token in text:
        frequency[token] += 1

texts = [[token for token in text if frequency[token] > 1]
          for text in docs]

# Create gensim dictionary object
dictionary = corpora.Dictionary(texts)

# Create corpus matrix
corpus = [dictionary.doc2bow(text) for text in texts]

# %%
lda = models.LdaModel(
    matutils.Sparse2Corpus(X, documents_columns=False),
    # or use the corpus object created with the dictionary in the previous frame!
    # corpus, 
    num_topics  =  3,
    passes      =  20,
    id2word     =  vocab
    # or use the gensim dictionary object!
    # id2word     =  dictionary
)

# %%
lda.print_topics(num_topics=3, num_words=5)
# Out:
# [(0,
#   u'0.073*citizens + 0.011*visas + 0.009*travel + 0.009*islands + 0.007*city'),
#  (1,
#   u'0.013*air + 0.006*luggage + 0.006*china + 0.004*proof + 0.004*schengen'),
#  (2,
#   u'0.018*airlines + 0.010*language + 0.006*new + 0.006*travel + 0.005*visa')]

# %%
lda.get_document_topics(corpus[0])
# Out:
# [(0, 0.083856002261188653),
#  (1, 0.083960948653453715),
#  (2, 0.83218304908535767)]

# %% [markdown]
# ## comments_train

# %%
comments_train.head()
# Out:
#               CreationDate  Id  PostId  Score  \
# 0  2011-06-21T20:25:14.257   1       1      0
# 1  2011-06-21T20:27:35.300   2       1      0
# 2  2011-06-21T20:32:23.687   3       1      3
# 3  2011-06-21T20:42:08.330   9      25      0
# 4  2011-06-21T20:44:09.990  12      26      3
#
#                                                 Text UserDisplayName  UserId
# 0  To help with the cruise line question: Where a...             NaN    12.0
# 1  Toronto, Ontario. We can fly out of anywhere t...             NaN     9.0
# 2  "Best" for what?  Please read [this page](http...             NaN    20.0
# 3  Are you in the UK? If so, would be helpful to ...             NaN    30.0
# 4  Where are you starting from, and what sort of ...             NaN    26.0

# %%
# Take Text column and set up so LDA is possible
vectorizer = CountVectorizer(stop_words='english')
X = vectorizer.fit_transform(comments_train.Text.values)

vectorizer.vocabulary_

docs = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names())

# %%
# Swap a dictionary key / value order.  This is the format gensim LDA expects it's vocabulary.
vocab = {v: k for k, v in vectorizer.vocabulary_.iteritems()}

# %%
vectorizer
# Out:
# CountVectorizer(analyzer=u'word', binary=False, decode_error=u'strict',
#         dtype=<type 'numpy.int64'>, encoding=u'utf-8', input=u'content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words='english',
#         strip_accents=None, token_pattern=u'(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
# remove words that appear only once
frequency = defaultdict(int)

for text in docs:
    for token in text:
        frequency[token] += 1

texts = [[token for token in text if frequency[token] > 1]
          for text in docs]

# Create gensim dictionary object
dictionary = corpora.Dictionary(texts)

# Create corpus matrix
corpus = [dictionary.doc2bow(text) for text in texts]

# %%
lda = models.LdaModel(
    matutils.Sparse2Corpus(X, documents_columns=False),
    # or use the corpus object created with the dictionary in the previous frame!
    # corpus, 
    num_topics  =  3,
    passes      =  20,
    id2word     =  vocab
    # or use the gensim dictionary object!
    # id2word     =  dictionary
)

# %%
lda.print_topics(num_topics=3, num_words=5)
# Out:
# [(0, u'0.024*http + 0.022*com + 0.019*travel + 0.014*flight + 0.013*www'),
#  (1, u'0.020*visa + 0.009*passport + 0.008*country + 0.007*uk + 0.007*don'),
#  (2, u'0.020*question + 0.016*answer + 0.010*just + 0.008*don + 0.008*like')]

# %%
lda.get_document_topics(corpus[0])
# Out:
# [(0, 0.77777262211098364), (1, 0.11111350880439701), (2, 0.11111386908461941)]

# %% [markdown]
# ## users

# %%
users = pd.read_csv('/Users/nichollejames/Desktop/DSI-SF-2-oboechick/projects/project-07/stack_exchange_travel/users.csv')

# %%
users.head()
# Out:
#                                              AboutMe  AccountId   Age  \
# 0  <p>Hi, I'm not really a person.</p>\n\n<p>I'm ...         -1   NaN
# 1  <p>Developer on the Stack Overflow team.  Find...          2  39.0
# 2  <p><a href="http://blog.stackoverflow.com/2011...       7598  31.0
# 3  <p>co-founder of <a href="https://airtable.com...       1998  30.0
# 4  <p><a href="http://blog.stackoverflow.com/2010...      29738   NaN
#
#               CreationDate     DisplayName  DownVotes  Id  \
# 0  2011-06-21T15:16:44.253       Community       8492  -1
# 1  2011-06-21T20:10:03.720    Geoff Dalgas          0   2
# 2  2011-06-21T20:11:02.490     Nick Craver          0   3
# 3  2011-06-21T20:12:21.223          Emmett          0   4
# 4  2011-06-21T20:15:31.410  Kevin Montrose          0   5
#
#             LastAccessDate                     Location  \
# 0  2011-06-21T15:16:44.253           on the server farm
# 1  2016-05-29T01:18:20.767                Corvallis, OR
# 2  2015-09-14T12:03:40.247            Winston-Salem, NC
# 3  2013-03-01T22:30:26.790            San Francisco, CA
# 4  2015-11-14T20:29:43.917  New York, NY, United States
#
#                                  ProfileImageUrl  Reputation  UpVotes  Views  \
# 0                                            NaN           1     2463      0
# 1                                            NaN         101        1     29
# 2            https://i.stack.imgur.com/nGCYr.jpg         101        1     13
# 3  https://i.stack.imgur.com/d1oHX.jpg?s=128&g=1         101        1      9
# 4                                            NaN         101        0      6
#
#                        WebsiteUrl
# 0  http://meta.stackexchange.com/
# 1        http://stackoverflow.com
# 2     http://nickcraver.com/blog/
# 3    http://minesweeperonline.com
# 4       http://kevinmontrose.com/

# %%
users['AboutMe'] = users.AboutMe.replace('Java', 'Nicholle')

# %%
users.AboutMe.dropna(axis=0)
# Out:
# 0        <p>Hi, I'm not really a person.</p>\n\n<p>I'm ...
# 1        <p>Developer on the Stack Overflow team.  Find...
# 2        <p><a href="http://blog.stackoverflow.com/2011...
# 3        <p>co-founder of <a href="https://airtable.com...
# 4        <p><a href="http://blog.stackoverflow.com/2010...
# 5        \n\n<p>I am a 2009 graduate of <a href="http:/...
# 6        <p>Currently studying Computer Programming and...
# 7        <p>I'm a django developer for a Travel company...
# 8        <p>I'm a software developer located in Layton,...
# 10       <p>I'm a Web Developer in New Orleans. I have ...
# 11       <p>I'm a software developer and Engineering gr...
# 13                                     <p>Beep boop.</p>\n
# 14       <p><a href="http://blog.stackoverflow.com/2011...
# 15                           Java Slave.. hem developer ;)
# 17       <h1>SOreadytohelp</h1>\n\n<p>.NET Developer si...
# 18       <p>Former Stack Exchange Community/Dev Team Me...
# 20       <p>A Dutch guy who lived a long time in Cusco,...
# 22       <p>President Fog Creek Software Inc.\nCEO Trel...
# 23       Application development, Web design, Integrati...
# 25                                        <p>Coding!</p>\n
# 26       <p><strong>Web software engineer.</strong></p>...
# 28                                     <p>wondering.</p>\n
# 29       <p>Game, web, and product developer/designer/e...
# 31           <p>Vexing Conundrums? I have solutions.</p>\n
# 32       <p>I love to travel, have seen much of Europe,...
# 33       <p>Not much of a developer/engineer, but will ...
# 34       <p>Weekend traveller.</p>\n\n<p>Countries: Aus...
# 35       <p>I am a developer, who likes to work on Pyth...
# 36       <p>I like all kinds of games but mostly strate...
# 37       <p>Infosec geek, infrastructure software engin...
#                                ...
# 29167                                <p>merge delete</p>\n
# 29173    <p>I picked up programming ~3 years ago during...
# 29174    <p>If you Want to know your pnr status check i...
# 29182    <p>Apparently, this user prefers to keep an ai...
# 29196                 <p>Sr.Software Design Engineer</p>\n
# 29197    <p>software development engineer, creating web...
# 29202    <p>GIS Analyst with a background in exploratio...
# 29209    <p>Web &amp; mobile apps developer #SOreadytoh...
# 29215    <p>enjoy using and learning new languages and ...
# 29225                <p>Just tryin' to stay alive...</p>\n
# 29232    <p>First learned to code in BASIC on a BBC Mod...
# 29234    <p>Lifelong VB programmer. Aspiring Python dev...
# 29242                        <p>Hobbyist Webdesigner</p>\n
# 29248    \n\n<p>I work for <a href="https://nzz.at/" re...
# 29258    <p>Apparently, this user prefers to keep an ai...
# 29261    <p>Apparently, this user prefers to keep an ai...
# 29262    <p><strong>Title :</strong>      learn more ab...
# 29263    <p>Kernel hacker\nC/C++ programmer\nJava/Andro...
# 29265    <p><strong>Title:</strong>       miami luxury ...
# 29267    <p><strong>Title:</strong>    Bel Air Luxury R...
# 29268    <p>Title:    Beverly Hills Luxury Real Estate ...
# 29269    <p>Title:  Website for Vero Beach Luxury Real ...
# 29270    <p>Doing research in formal methods, control t...
# 29271                               <p>Web developer</p>\n
# 29272    <p><strong>Title:</strong> San Francisco Luxur...
# 29273                       <p>Apps that ring a bell</p>\n
# 29275    <p>Short version: I'm a software developer and...
# 29276    <p>PhD student in X-ray tomographic reconstruc...
# 29278          <p>Software and technology enthusiast</p>\n
# 29279    <p>I've been working as a software developer s...
# Name: AboutMe, dtype: object

# %%
users.shape
# Out:
# (29283, 14)

# %%
users_bs = users.AboutMe.values

# %%
users_bs
# Out:
# ['<p>Hi, I\'m not really a person.</p>\n\n<p>I\'m a background process that helps keep this site clean!</p>\n\n<p>I do things like</p>\n\n<ul>\n<li>Randomly poke old unanswered questions every hour so they get some attention</li>\n<li>Own community questions and answers so nobody gets unnecessary reputation from them</li>\n<li>Own downvotes on spam/evil posts that get permanently deleted</li>\n<li>Own suggested edits from anonymous users</li>\n<li><a href="http://meta.stackexchange.com/a/92006">Remove abandoned questions</a></li>\n</ul>\n',
#  '<p>Developer on the Stack Overflow team.  Find me on</p>\n\n<p><a href="http://www.twitter.com/SuperDalgas" rel="nofollow">Twitter</a>\n<br><br>\n<a href="http://blog.stackoverflow.com/2009/05/welcome-stack-overflow-valued-associate-00003/">Stack Overflow Valued Associate #00003</a></p>\n',
#  '<p><a href="http://blog.stackoverflow.com/2011/01/welcome-valued-associate-nick-craver/">Stack Overflow Valued Associate</a></p>\n\n<p>Twitter: <a href="http://twitter.com/Nick_Craver" rel="nofollow">@Nick_Craver</a><br>\nPublic CV: <a href="http://careers.stackoverflow.com/ncraver">On StackOverflow Careers</a><br>\nFlickr: <a href="http://www.flickr.com/photos/nickcraver/" rel="nofollow">Photos on new house progress, where I work, etc.</a></p>\n\n<p>I mostly live in the C#/Linq2SQL/Raw SQL world, but at night I secretly masquerade as someone who pretends to know <a href="http://stackoverflow.com/questions/tagged/javascript">JavaScript</a> &amp; <a href="http://stackoverflow.com/questions/tagged/jquery">jQuery</a>.<br>\n<sub>Disclaimer: I have <em>no idea</em> what I\'m talking about, all my answers are guesses!</sub></p>\n',
#  '<p>co-founder of <a href="https://airtable.com" rel="nofollow">Airtable</a></p>\n\n<p>formerly a dev at Stack Exchange :)</p>\n',
#  '<p><a href="http://blog.stackoverflow.com/2010/03/welcome-stack-overflow-valued-associate-000004/">Stack Overflow Valued Associate #00004</a></p>\n\n<p>For no good reason, <a href="http://twitter.com/kevinmontrose" rel="nofollow">I\'m on twitter</a>.  I hear its compelling... somehow.<br/></p>\n\n<p>I also have a <a href="http://kevinmontrose.com" rel="nofollow">blog</a>.</p>\n',
#  '\n\n<p>I am a 2009 graduate of <a href="http://www.case.edu" rel="nofollow">Case Western Reserve University</a> with a degree in computer science, and since then I\'ve worked as a software engineer for <a href="http://www.louddoor.com" rel="nofollow">LoudDoor</a>, a Columbia, SC-based startup. In 2015, we launched <a href="http://www.storylift.com" rel="nofollow">Storylift</a>, a content marketing solution. I work primarily in PHP, Go and Javascript (jQuery) (along with HTML/CSS), but have some .NET experience and have dabbled in a few other languages. I also maintain a bunch of <a href="http://jimmysawczuk.com/projects" rel="nofollow">smaller projects</a> on the side. When I\'m not coding, I enjoy running, reading, and watching baseball.</p>\n',
#  '<p>Currently studying Computer Programming and Analysis at Seneca College in Toronto, ON, Canada.  Past Graduate of Sports and Leisure Management at Holland College in Charlottetown, PE, Canada and former student of Business Administration at Durham College.  I consider myself a professional student..   </p>\n',
#  "<p>I'm a django developer for a Travel company in Toronto.</p>\n",
#  '<p>I\'m a software developer located in Layton, UT.</p>\n\n<p>I currently work for <a href="http://devresults.com" rel="nofollow">DevResults</a> solving important problems.</p>\n',
#  nan,
#  "<p>I'm a Web Developer in New Orleans. I have moderate experience with PHP, jQuery, javascript, HTML, CSS, Ruby, and Rails. Getting into HTML5, CSS3, and coffeescript. Want to learn Python and much much more Ruby.</p>\n",
#  '<p>I\'m a software developer and Engineering graduate of the University of Waterloo, currently looking for new opportunities in New York City.</p>\n\n<p><a href="http://careers.stackoverflow.com/matthewryanread">Stack Overflow Careers</a> | <a href="http://ca.linkedin.com/in/matthewryanread" rel="nofollow">LinkedIn</a></p>\n',
#  nan,
#  '<p>Beep boop.</p>\n',
#  '<p><a href="http://blog.stackoverflow.com/2011/02/welcome-valued-associate-jamie-gingerelli/">Ad Operations Manager</a>- Stack Exchange</p>\n\n<p>Curating ads on SO, and so much more.. Questions, comments, concerns- I\'m here to help. Complaints, go somewhere else :)</p>\n',
#  'Java Slave.. hem developer ;)',
#  nan,
#  '<h1>SOreadytohelp</h1>\n\n<p>.NET Developer since 2005<br>\nMCPD (.NET 3.5)</p>\n\n<p><a href="http://stackexchange.com/users/d4a5409417ff4d129764cc85272e5237">\n<img src="http://stackexchange.com/users/flair/d4a5409417ff4d129764cc85272e5237.png?theme=dark" width="208" height="58" alt="profile for VMAtm on Stack Exchange, a network of free, community-driven Q&amp;A sites" title="profile for VMAtm on Stack Exchange, a network of free, community-driven Q&amp;A sites">\n</a></p>\n',
#  '<p>Former Stack Exchange Community/Dev Team Member.</p>\n\n<p>I\'m <a href="http://twitter.com/rchern" rel="nofollow">@rchern</a> on Twitter.</p>\n\n<p>You can email me at rebecca.chernoff on gmail.</p>\n',
#  nan,
#  '<p>A Dutch guy who lived a long time in Cusco, Peru since 1998. Via Fuengirola, Spain, I have moved back to Holland where I am now living and working.</p>\n\n<p>My activities range from web-site design and development to travelling through Argentina, Chile, Bolivia and Peru as a tour guide.</p>\n\n<p><a href="http://www.jeronimodesign.com/" rel="nofollow">http://www.jeronimodesign.com/</a><br>\n<a href="http://careers.stackoverflow.com/jeroen">http://careers.stackoverflow.com/jeroen</a></p>\n',
#  nan,
#  '<p>President Fog Creek Software Inc.\nCEO Trello Inc.</p>\n',
#  'Application development, Web design, Integrating RTS are my passions. Having more then ten years of quality experience involving deeply into various phases of development and implementation using cutting edge technologies in Java, J2EE and allied technologies.',
#  nan,
#  '<p>Coding!</p>\n',
#  '<p><strong>Web software engineer.</strong></p>\n\n<p>Server (Java, PHP) and UI (JS, CSS)</p>\n\n<p>Designer and photographer on the side.</p>\n\n<p>I\'m a serial user of the double <code>__</code> space after a period &mdash; even though people tell me it\'s obsolete in the computer-world, I can\'t shake the habit from my 7th grade typing class.</p>\n\n<p><a href="http://stackexchange.com/users/80454853af1a4c75946da39043ee6b44">\n<img src="http://stackexchange.com/users/flair/80454853af1a4c75946da39043ee6b44.png" width="208" height="58" alt="profile for NickC on Stack Exchange, a network of free, community-driven Q&amp;A sites" title="profile for NickC on Stack Exchange, a network of free, community-driven Q&amp;A sites">\n</a></p>\n\n<pre><code>#SOreadytohelp\n</code></pre>\n',
#  nan,
#  '<p>wondering.</p>\n',
#  '<p>Game, web, and product developer/designer/entrepreneur</p>\n\n<p><a href="http://wicklandgame.com" rel="nofollow">wicklandgame.com</a></p>\n\n<p><a href="http://ubiqvisuals.com" rel="nofollow">ubiqvisuals.com</a></p>\n\n<p><a href="http://mohzy.com" rel="nofollow">mohzy.com</a></p>\n',
#  nan,
#  '<p>Vexing Conundrums? I have solutions.</p>\n',
#  "<p>I love to travel, have seen much of Europe, a little bit of the US, almost nothing of Australia, Asia and America, and I'm deeply in love with New Zealand.</p>\n",
#  '<p>Not much of a developer/engineer, but will probably be hiring a few in the new future. Here to know what I don\'t know. Co-founder of <a href="http://www.rarepink.com/diamond-engagement-rings" rel="nofollow">Diamond Engagement Ring</a> retailer Rare Pink.</p>\n',
#  '<p>Weekend traveller.</p>\n\n<p>Countries: Austria, Belgium, Bulgaria, Canada (BC, ON), Croatia, Cyprus (Cyprus, "Turkish Republic of Northern Cyprus"), Czech Republic, Denmark, Estonia, Finland, France, Germany, Greece, Hungary, Ireland, Italy (mainland, the Holy See, Sardinia, Sicily), Latvia, Lithuania, Luxembourg, Malta, Netherlands, Norway, Poland, Portugal (mainland, Madeira), Romania, Slovakia, Slovenia, Spain (mainland, Balearics (Ibiza, Mallorca, Minorca), Canaries (Fuerteventura, Gran Canaria, Lanzarote, Tenerife)), Sweden, Switzerland, Turkey, United Kingdom (England, Gibraltar, Isle of Man, Northern Ireland, Scotland, Wales) and the US&amp;A (CA, CT, DC, MA, MD, NV, NY, RI, VA, WA).</p>\n\n<p>Airports: ABZ, ACE, AGP, ALC, AMS, ANR, ARN, ATH, BBU, BCN, BFS, BGO, BHD, BHX, BLK, BOS, BRS, BRU, BSL, BUD, CCF, CDG, CGN, CPH, CRL, CWL, DBV, DCA, DFW, DUB, DUS, EAP, EDI, EMA, EWR, EXT, FAO, FCO, FRA, FDH, FNC, FUE, GIB, GLA, GVA, HAM, HEL, IBZ, IOM, IST, KRK, LAS, LCA, LCY, LGW, LHR, LIN, LIS, LJU, LPA, LTN, MAD, MAH, MAN, MKE, MLA, MLH, MRS, MUC, NAP, NCL, NQY, NWI, OLB, OPO, ORK, ORY, PRG, RIX, RLL, SDR, SEA, SEN, SFO, SJC, SKG, SOF, SOU, STN, STR, SWS, SXF, TFS, TNN, VCE, VIE, VNO, VRN, YTZ, YVR, YYJ, ZGB, ZRH and RAF Edgehill [unpowered aircraft only]</p>\n\n<p>New airports coming up: BLQ, AOI</p>\n\n<p>Airlines: Aegean, Aer Lingus, AirTran, Air Aaron, Air Baltic, Air Canada, Air France, Air Malta, American Airlines, BA CityFlyer, Binter Canarias, BMI, British Airways, Brussels Airlines, CityJet, Coastal Pacific, Continental, EasyJet, Flybe, Iberia, Isla, Jet2, KLM, Manx2 (now "CityWing"), Meridiana, Monarch, Norwegian, Porter, Ryanair, SAS, Southwest, Swiss, TAP Portugal, United, US Airlines, Virgin Atlantic, Wizz.</p>\n\n<p>Most hated airlines:</p>\n\n<ol>\n<li>Meridiana</li>\n<li>United</li>\n<li>Monarch</li>\n<li>Wizz</li>\n<li>Ryanair</li>\n<li>American</li>\n</ol>\n\n<p>Aeroplanes: A300, A319, A320, A321, A330, A340, A380, ATR42, ATR72, B1900C, 717, 737, 747, 757, 767, 777, Cessna?, Dash-8/Q400, ERJ145, E170, E190, E195, L-410, MD80, RJ85, RJ100 and a couple of gliders</p>\n\n<p>I11l ferries: Bratislava -> Budapest, Dublin &lt;-> Holyhead &lt;-> Dun Laoghaire, Tallinn -> Helsinki, Victoria -> Seattle</p>\n\n<p>Intercontinental ferries: Istanbul</p>\n\n<p>I11l walks: (Cyprus - "TRNC"), France/Germany/Switzerland, Spain - UK.</p>\n\n<p>I11l train borders: Italy &lt;-> Switzerland -> Austria -> Germany &amp; Slovakia, Netherlands &lt;-> Belgium &lt;-> France &lt;-> UK.</p>\n\n<p>I11l coach due to rail strike: Belgium -> Luxembourg.</p>\n\n<p>Bed bugs: Washington DC, Catania, Luxembourg.</p>\n\n<p>To do before I\'m 45 (unlikely):</p>\n\n<ul>\n<li>EU capitals: Warsaw.</li>\n<li>Islands: Iceland, Isles of Scilly, Jersey, Guernsey,\n   Azores\n   and at least two significant Greeks.</li>\n<li>European countries: Ukraine (perhaps San Marino,\n   Liechtenstein, Monaco; probably not Andora)</li>\n<li>Northmost Africa: Morocco, Tunisia, Egypt and probably others.</li>\n<li>Germany: Hannover, Dresden</li>\n<li>And: Japan, Melbourne, Sydney, bits of NZ, a pacific island or two.</li>\n</ul>\n',
#  '<p>I am a developer, who likes to work on Python and C. I use vim editor for most of my tasks. Use mutt as an email client, chrome and firefox for browsing the www. A custom minimal ubuntu is my OS.</p>\n\n<p>I am a Python Core Developer and I work on Internet protocol modules such as urllib, urlparse and other related ones.</p>\n\n<p>Visit my programming site at <a href="http://www.uthcode.com" rel="nofollow">http://www.uthcode.com</a></p>\n',
#  '<p>I like all kinds of games but mostly strategy and RPGs \nHere is a list of some games I have played and my thoughts <a href="http://bronzebeard.wordpress.com/games/" rel="nofollow">http://bronzebeard.wordpress.com/games/</a></p>\n',
#  '<p>Infosec geek, infrastructure software engineer, hacker-of-all-trades, mom, martial artist, weightlifter, fountain pen geek, and backpacker from Bloomington, IN.</p>\n',
#  nan,
#  '<p>Software developer at Fujifilm Medical Systems</p>\n',
#  '<p>Software Developer, Photographer. Or the other way around.</p>\n\n<ul>\n<li><a href="http://alfredmyers.com/" rel="nofollow" title="Alfred Myers">Blog</a> </li>\n<li><a href="http://alfredmyers.photography/" rel="nofollow" title="Alfred Myers Photography">Alfred Myers Photography</a> </li>\n<li><a href="http://sampa.guide/" rel="nofollow" title="Sampa Guide">Sampa Guide</a></li>\n</ul>\n',
#  nan,
#  '<p>Mostly holiday travelling, usually with kids.</p>\n\n<p><a href="http://i.stack.imgur.com/9V0sK.png" rel="nofollow"><img src="http://i.stack.imgur.com/9V0sK.png" alt="enter image description here"></a></p>\n',
#  nan,
#  '<p>Consultant, developer, mentor, author, speaker. C++ and .NET, Windows 7, Sharepoint, whatever else I like.</p>\n\n<p><img src="http://www.traveltip.org/pix/user_countries.php?user=gregcons&amp;s=sm" alt="Countries I\'ve visited"></p>\n',
#  '<p>A web developer that enjoys photography and wandering around.</p>\n',
#  "<p>I'm not a developer, i'm just crazy joe user.</p>\n",
#  '<p><a href="http://richadams.me" rel="nofollow">richadams.me</a> (my site) &middot; <a href="http://wblinks.com" rel="nofollow">wblinks.com</a> (also my site)</p>\n\n<p><strong>Fun Facts About Rich:</strong></p>\n\n<ul>\n<li>By day, I\'m an operations engineer at <a href="https://www.pagerduty.com" rel="nofollow">PagerDuty</a>, by night/spare-time I\'m a <del>crime fighting superhero</del> web developer.</li><br/>\n<li>I\'m British, but live in San Francisco.</li><br/>\n<li>I like curry... and Mountain Dew... but not together.</li>\n</ul>\n\n<p><br/>\n<em>This is my personal account. Any views expressed in any post/comment I make are mine alone and not those of my employer.</em></p>\n',
#  nan,
#  nan,
#  "<p>Get outta my way, I'm changin' the world - and no one's gonna tell me otherwise.</p>\n",
#  '<p><em><strong>Android, iOS and Web Developer</em></strong></p>\n\n<ul>\n<li>Web Developer since 1997</li>\n<li>Embedded Systems Engineer since 2005</li>\n<li>Android Developer since the first Android 1.0 release in 2008</li>\n<li>iOS Developer since 2009</li>\n</ul>\n\n<p><em>Minimalist. Interested in Software Engineering, Psychology and Design. Passion for Excellence. Kitesurf Addict.</em></p>\n\n<p>Have a look at my <a href="http://stefanklumpp.com/cv.html" rel="nofollow">full CV</a> and see what other <a href="http://stefanklumpp.com/testimonials.html" rel="nofollow">people say about me</a>. </p>\n\n<p>Find out more about me on my <a href="http://stefanklumpp.com" rel="nofollow">website</a>, my <a href="http://geekmind.net" rel="nofollow">tech blog</a> or <a href="http://twitter.com/stefanklumpp" rel="nofollow">follow me on Twitter</a>.</p>\n\n<p>I love reading <a href="http://stefanklumpp.com/books.html" rel="nofollow">books</a>, doing yoga and drinking tea.</p>\n\n<p>I run <a href="http://mobilejazz.cat" rel="nofollow">Mobile Jazz</a>, an engineering and design company where we build beautiful applications for startups.</p>\n',
#  '<p>I am:</p>\n\n<ul>\n<li>the co-founder and CEO of <a href="http://stackexchange.com">Stack Exchange</a></li>\n<li>the co-founder of <a href="http://www.fogcreek.com" rel="nofollow">Fog Creek Software</a></li>\n<li>the creator and chairman of the board of <a href="http://trello.com" rel="nofollow">Trello</a></li>\n<li>owner of Taco, the most famous Siberian Husky on the Upper West Side.</li>\n</ul>\n\n<p>You can find me on Twitter (as <a href="http://twitter.com/spolsky" rel="nofollow">@spolsky</a>) or on my rarely-updated blog, <a href="http://joelonsoftware.com" rel="nofollow">Joel on Software</a>.</p>\n',
#  '<p><a href="http://meta.stackexchange.com/questions/99338/who-are-the-community-team-and-what-do-they-do/99341#99341">Community Manager for Stack Overflow and Stack Exchange</a>  </p>\n\n<p>I talk a lot. Read the bits in bold. Question everything. </p>\n\n<p>If necessary, you may contact me via email sent to stackoverflow.com - the address would begin with shog@</p>\n\n<p>Poke...</p>\n',
#  nan,
#  nan,
#  "I'm a C#, PHP, HTML, CSS, JavaScript programmer in that order. I also know me some Java, C/C++ and Assembler.",
#  nan,
#  nan,
#  '<p>Software Engineer at Pardot, A Salesforce.com company.</p>\n',
#  '<p>Hi. I\'m Keith. I answer questions about video games. I also delete spam. And write opinionated meta posts. And assorted other Moderatorial things.</p>\n\n<p>If you need to reach out to me for any reason, I can always be reached in the following ways:</p>\n\n<p>I am <a href="https://twitter.com/lesspopmorefizz" rel="nofollow">@lesspopmorefizz on Twitter</a>. I am <a href="http://steamcommunity.com/id/lesspopmorefizz/" rel="nofollow">LessPopMoreFizz on Steam</a>.</p>\n\n<p>Keith at lesspopmorefizz dot com is my email address. It also works for Google Talk.</p>\n',
#  "<p>Emergency Room Nurse with a passion for cooking!</p>\n\n<p>Also with a Bachelor's in Biology with a minor in Chemistry!  Science geek all around!</p>\n",
#  '<p>Web Application Developer, Peace Corps Volunteer, WWOOFer, Traveler.</p>\n\n<p><a href="http://pcvcharlie.blogspot.com/" rel="nofollow">http://pcvcharlie.blogspot.com/</a></p>\n',
#  '<p>Software Engineer living in Brisbane. Likes Python, working with data.</p>\n\n<p>Founder of <a href="http://drknow.co" rel="nofollow">Dr Know</a>, a startup to simplify reminders and bookings for health checks via SMS. Winner of Australia\'s First Startup Weekend for Health.</p>\n',
#  'Software developer who likes video games and robotics.',
#  '<p><a href="http://blog.stackoverflow.com/2009/01/welcome-stack-overflow-valued-associate-00002/">Developer on the Stack Overflow team</a>.</p>\n\n<p>Was dubbed <strong>SALTY SAILOR</strong> by Jeff Atwood, as filth and flarn would oft-times fly when dealing with a particularly nasty bug!</p>\n\n<ul>\n<li>Twitter me: <a href="http://twitter.com/jarrod_dixon" rel="nofollow">jarrod_dixon</a></li>\n<li>Email me: jarrod.m.dixon@gmail.com</li>\n</ul>\n',
#  "<p>I've spent three years living in China, and speak pretty reasonable Chinese (+ my girlfriend is a translator). I love Macs, travel, and the internet, and I'm always trying to get in shape. Anything else you'd like to know? Just ask.</p>\n",
#  nan,
#  '<ul>\n<li>Windows/SQL Server stack via MFC &amp; .NET</li>\n<li>Linux via Java</li>\n<li>Project Euler via Python</li>\n</ul>\n\n<p>Some of my SO/SE participation:</p>\n\n<ul>\n<li><a href="http://stackoverflow.com/questions/5937104/how-to-manage-large-set-of-data-on-a-mobile-device/5937161#5937161">How to manage large set of data on a mobile device</a></li>\n<li><a href="http://programmers.stackexchange.com/questions/43214/how-do-you-educate-your-teammates-without-seeming-condescending-or-superior/43222#43222">How to educate your teammates without seeming condescending or superior?</a></li>\n<li><a href="http://stackoverflow.com/questions/2653096/why-use-mvvm/2653145#2653145">Why use MVVM???</a></li>\n<li><a href="http://stackoverflow.com/questions/1973050/im-rewriting-my-code-around-10-times-before-finishing-is-this-wrong/1973068#1973068">I&#39;m rewriting my code around 10 times before finishing. Is this wrong?</a></li>\n<li><a href="http://stackoverflow.com/questions/4378068/when-to-use-a-view-instead-of-a-table/4378124#4378124">When to use a View instead of a Table?</a></li>\n<li><a href="http://stackoverflow.com/questions/2291455/fuzzy-match-in-c/2291478#2291478">Fuzzy match in C#</a></li>\n<li><a href="http://stackoverflow.com/questions/4707607/what-are-good-algorithms-for-vehicle-license-plate-detection/4707676#4707676">What are good algorithms for vehicle license plate detection?</a></li>\n<li><a href="http://stackoverflow.com/questions/2680046/what-is-the-best-euphemism-for-a-non-developer/2680076#2680076">What is the best euphemism for a non-developer?</a></li>\n<li><a href="http://stackoverflow.com/questions/5545013/mysql-what-does-r-mean/5545036#5545036">mysql: what does &#39;r&#39; mean?</a></li>\n<li><a href="http://stackoverflow.com/questions/2076370/most-underused-data-visualization/2076384#2076384">Most underused data visualization</a></li>\n</ul>\n',
#  '<p><a href="http://www.codinghorror.com/blog/archives/001169.html" rel="nofollow">Stack Overflow Valued Associate #00001</a></p>\n\n<p>Wondering how our software development process works? <a href="http://www.youtube.com/watch?v=08xQLGWTSag" rel="nofollow">Take a look!</a></p>\n\n<p>Find me <a href="http://twitter.com/codinghorror" rel="nofollow">on twitter</a>, or <a href="http://www.codinghorror.com/blog" rel="nofollow">read my blog</a>. Don\'t say I didn\'t warn you <em>because I totally did</em>.</p>\n\n<p>However, <a href="http://www.codinghorror.com/blog/2012/02/farewell-stack-exchange.html" rel="nofollow">I no longer work at Stack Exchange, Inc</a>. I\'ll miss you all. Well, <em>some</em> of you, anyway. :)</p>\n',
#  nan,
#  '<p>SharePoint MVP from Croatia, SharePoint geek, entrepreneur, consultant... My blog: <a href="http://www.sharepointusecases.com" rel="nofollow">SharePoint Use Cases</a>, <a href="http://twitter.com/tonifrankola" rel="nofollow">@ToniFrankola</a>.</p>\n\n<p>Check out our latest SharePoint product: <a href="http://www.spdockit.com" rel="nofollow">Documentation Toolkit for SharePoint</a>.</p>\n',
#  '<h3>Current status: looking for employment. Got something? Let\'s talk.</h3>\n\n<p><strong><a href="http://www.dori.com" rel="nofollow">Dori Smith</a></strong> is the best-selling co-author of <em><a href="http://www.javascriptworld.com" rel="nofollow">JavaScript: Visual QuickStart Guide, 9<sup>th</sup> edition</a></em>; <em><a href="http://www.dreamweaverbook.com" rel="nofollow">Dreamweaver: Visual QuickStart Guide</a></em>; <em>Styling Web Pages with CSS: Visual QuickProject Guide</em>; and <em><a href="http://www.macosxunwired.com" rel="nofollow">Mac OS X Unwired</a></em>. She also created the videos <em>JavaScript Essential Training</em> and <em>Ajax Essential Training</em> for <a href="http://www.lynda.com" rel="nofollow">Lynda.com</a>, wrote <em>Java 2: Visual QuickStart Guide</em> and contributes to numerous online and print computer industry magazines. A frequent speaker at industry conferences, she was a founding member of the <a href="http://www.webstandards.org" rel="nofollow">Web Standards Project</a> and is Publisher and ListMom for the <a href="http://www.wise-women.org" rel="nofollow">Wise-Women\'s Web community</a>. She co-founded and contributes to the long-running <a href="http://www.backupbrain.com" rel="nofollow">Backup Brain weblog</a>. </p>\n\n<p>She can also be found at:</p>\n\n<blockquote>\n  <p><img src="https://s2.googleusercontent.com/s2/favicons?domain=twitter.com" alt="Twitter logo"> <a href="http://twitter.com/dori" rel="nofollow">Twitter</a><br>\n  <img src="https://s2.googleusercontent.com/s2/favicons?domain=linkedin.com" alt="LinkedIn logo"> <a href="http://www.linkedin.com/in/dorismith" rel="nofollow">LinkedIn</a><br>\n  <img src="https://s2.googleusercontent.com/s2/favicons?domain=plus.google.com" alt="G+ logo"> <a href="https://plus.google.com/117004257332029851484/" rel="nofollow">Google+</a><br>\n  <img src="https://s2.googleusercontent.com/s2/favicons?domain=github.com" alt="GitHub logo"> <a href="http://github.com/dori" rel="nofollow">Github</a><br>\n  <img src="https://s2.googleusercontent.com/s2/favicons?domain=www.facebook.com" alt="Facebook logo"> <a href="http://www.facebook.com/dorismith" rel="nofollow">Facebook</a> (personal)<br>\n  <img src="https://s2.googleusercontent.com/s2/favicons?domain=www.facebook.com" alt="Facebook logo"> <a href="http://www.facebook.com/TheDoriSmith" rel="nofollow">Facebook</a> (professional)<br></p>\n</blockquote>\n\n<p><a href="http://stackexchange.com/users/6489/dori"><img src="http://stackexchange.com/users/flair/6489.png" alt="Flair"></a></p>\n',
#  nan,
#  'Primarily a Java programmer but have dabbled in C, Python, JSP and many others.\r\nLove football (soccer) and my PS3.',
#  '<p>(\xe2\x95\xaf\xc2\xb0\xe2\x96\xa1\xc2\xb0)\xe2\x95\xaf\xef\xb8\xb5 \xe2\x94\xbb\xe2\x94\x81\xe2\x94\xbb</p>\n',
#  '<p>Currently playing with Android and Rails while working with Python/Django on week days.  When I have questions, I will try to give examples based on current events or food so that they are more exciting to answer.</p>\n\n<p>Plus I build stuffs that are useful to me.</p>\n',
#  nan,
#  '<p></p>\n',
#  '<p>I am <a href="http://nicolas-raoul.blogspot.com" rel="nofollow">Nicolas Raoul</a>, IT consultant in Tokyo.</p>\n\n<p>Feel free to copy/paste the source code from my StackExchange answers, I release it to the public domain.</p>\n',
#  'Just a normal guy trying to program his way out of problems',
#  '<p>Code Monkey!</p>\n\n<p>My new thing: <a href="http://www.taiwanease.com" rel="nofollow">http://www.taiwanease.com</a></p>\n\n<p><a href="http://itunes.apple.com/us/app/taiwanease/id515864552?mt=8" rel="nofollow">http://itunes.apple.com/us/app/taiwanease/id515864552?mt=8</a></p>\n',
#  nan,
#  '<p>mid-level asp.net web application developer.</p>\n',
#  '<p>Web Developer and musician wanna be.</p>\n\n<p>twitter account <a href="http://twitter.com/#!/pheano" rel="nofollow">@pheano</a><br>\nwordpress blog <a href="http://pheli0x.wordpress.com" rel="nofollow">Phelio Gnomi</a></p>\n',
#  '<p>Java programmer ,Web developer<br></p>\n\n<p><br>http://www.delicious.com/pramodc84<br></p>\n\n<p><br>http://www.twitter.com/pramodc84</p>\n\n<p><br>http://www.facebook.com/pramodc84</p>\n',
#  '<p><strong>software</strong> guy, at <strong>Neocis</strong>, former <strong>CMake</strong> release manager, contributor to <strong>VTK</strong> and <strong>ITK</strong>, ex <strong>Visio</strong> dev, creator of <strong>Sgt Fitness</strong> &amp; <strong>Frackle</strong> iPhone apps</p>\n\n<p>Interested in:</p>\n\n<ul>\n<li>build stuff</li>\n<li>graphics stuff</li>\n<li>iPhone and iPad stuff</li>\n<li>world travel</li>\n<li>good (coffee, beer, steak, chocolate, Scotch), perhaps, but not necessarily, in that order</li>\n</ul>\n',
#  nan,
#  "<p>I'm a CS Master Student, interested in Mobile Device Programming</p>\n",
#  '<p>I am <a href="http://www.amanjain.com" rel="nofollow">Aman Kumar Jain</a>, a Pune (India) based Software Professional.  #SOreadytohelp</p>\n',
#  'Management geek',
#  '<p>get the bug ? get the book</p>\n',
#  '<p>Rails and iOS Developer</p>\n',
#  '\n\n<p>I write SQL queries, PL/SQL programs or develop UI using Oracle Forms. Former <a href="http://techie-buzz.com/author/sathya" rel="nofollow">techie-buzz</a> blogger. Occasionally write a post or two on my own blogs <a href="http://sathyabh.at" rel="nofollow">personal</a> and <a href="http://sathyasays.com" rel="nofollow">tech</a>. #SOreadytohelp</p>\n\n<p>I used to moderate (the now defunct) <a href="http://tech2.in.com/forum/forum.php" rel="nofollow">tech2 forums</a> and was <a href="http://blog.stackoverflow.com/2011/02/welcome-our-new-trilogy-moderators-for-2011/">elected as a \xe2\x99\xa6 Community Moderator</a> for <a href="http://superuser.com/users/4377">Super User</a> in 2011 and for <a href="http://meta.webapps.stackexchange.com/q/1210/310">Web Applications Stack Exchange in 2012</a>. </p>\n\n<p>Besides SQL, PL/SQL &amp; Oracle Forms, I also know a little bit of Ruby, Python &amp; C#. I love <a href="http://last.fm/user/sathyabhat" rel="nofollow">listening to music</a> and I\'m an avid gamer, and can be found on <a href="http://raptr.com/sathyabhat" rel="nofollow">Raptr</a>, <a href="http://steamcommunity.com/id/sathyabhat" rel="nofollow">Steam</a>.</p>\n\n<p>I have a rather broad social presence and you can catch me on <a href="http://twitter.com/sathyabhat" rel="nofollow">twitter</a>, <a href="http://facebook.com/sathyabhat" rel="nofollow">facebook</a>, <a href="http://linkedin.com/in/sathyabhat" rel="nofollow">LinkedIn</a>,  <a href="https://plus.google.com/u/0/102438636933093151901/about" rel="nofollow">Google+</a> <a href="http://post.sathyabh.at" rel="nofollow">Posterous</a>, <a href="http://tumble.sathyabh.at" rel="nofollow">Tumblr</a>, <a href="http://www.google.com/reader/shared/10711434258154108770" rel="nofollow">Google Reader</a>, <a href="http://sbhat.me" rel="nofollow">about.me</a> and <a href="http://sathya.pro" rel="nofollow">Atticous</a> </p>\n\n<p>I also tend to edit quite a lot of questions and answers - so please don\'t think I\'m targetting you. </p>\n\n<p>BTW - there\'s my <a href="http://u.sbhat.me/jK1HHL" rel="nofollow">Amazon Wish List</a> that needs to be fulfilled :)  </p>\n\n<hr>\n\n<p>[showoff]</p>\n\n<p><strong>HP Envy 14</strong></p>\n\n<p><a href="http://www.flickr.com/photos/sathyabhat/tags/envy" rel="nofollow" title="HP Envy 14"><img src="http://farm5.static.flickr.com/4133/5053080990_aab40e58e1_m.jpg" width="240" height="180" alt="P1000926" /></a></p>\n\n<p><strong>Google Cr-48</strong></p>\n\n<p><a href="http://www.flickr.com/photos/sathyabhat/tags/cr48" rel="nofollow" title="My Cr-48"><img src="http://farm6.static.flickr.com/5042/5281767118_78d2dc0746_m.jpg" width="240" height="180" alt="Say hello to my Cr-48" /></a></p>\n\n<p><strong>D-Link DGL 4500</strong></p>\n\n<p><a href="http://www.flickr.com/photos/sathyabhat/tags/dgl4500/" rel="nofollow" title="D-Link DGL 4500, sent by @Jeff Atwood"><img src="http://farm5.static.flickr.com/4131/5031648434_d5070ed2e5_m.jpg" width="240" height="180" alt="D-Link DGL 4500" /></a></p>\n\n<p><strong>Denon AH-C360</strong></p>\n\n<p><a href="http://www.flickr.com/photos/sathyabhat/tags/denon/" rel="nofollow" title="Denon AH-C360"><img src="http://farm5.static.flickr.com/4082/4949889258_c340d32591_m.jpg" width="180" height="240" alt="img_2014.jpg" /></a></p>\n\n<p><strong>Fiio E5</strong></p>\n\n<p><a href="http://www.flickr.com/photos/sathyabhat/tags/fiio/" rel="nofollow" title="Fiio E5 amp"><img src="http://farm5.static.flickr.com/4009/4375895578_64d15c8472_m.jpg" width="180" height="240" alt="Fiio E5 amp is in the house" /></a></p>\n\n<p>[/showoff]</p>\n',
#  '<p>A Strategist. Ruby on Rails (RoR) Web Developer with more than 5 years of experience in various industries. <a href="http://bit.ly/Oue4s" rel="nofollow">Click here to see About Arie</a>.</p>\n',
#  nan,
#  '<p>Developer. Engineer. Enthusiast. Goodjer. Bugler.</p>\n',
#  '<p>Follow me on <a href="https://twitter.com/#!/marksmayo" rel="nofollow">@marksmayo on twitter!</a>\n<hr>\nI also compete to find cheap flights on <a href="http://darjeelin.com/a/HGKDXP" rel="nofollow">Darjeelin</a> (referral link).\n<hr>\nMy top question - <a href="http://travel.stackexchange.com/q/1224/101">Tactics to avoid getting harassed by corrupt police</a></p>\n\n<p>My top answer - <a href="http://travel.stackexchange.com/a/26640/101">When I travel next, I want to reach the point on the earth that is exactly opposite my home, how can I discover where that is?</a>\n<hr>\n<strong>Currently in</strong> Sydney, Australia, contracting before my next trip...\n<hr>\n<strong>Kiwi travelling addict</strong>, 73+ countries, living a non-conventional life, fitting in software contracting between travel, photography and the odd bit of writing.\n<hr>\n<strong>Have visited</strong> : Argentina, Australia, Austria, Bahrain, Belgium, Bolivia, Bosnia, Brazil, Bulgaria, Canada, Chile, China, Ciskei, Croatia, Colombia, Cuba, Czech Republic, Denmark, Ecuador, Egypt, England, Estonia, Finland, France, Germany, Hong Kong, Hungary, Iran, Ireland, Japan, Jordan, Kazakhstan, Kyrgyzstan, Latvia, Lithuania, Luxembourg, Malaysia, Mexico, Mongolia, Morocco, Netherlands, New Zealand, Northern Ireland, Norway, Oman, Paraguay, Peru, Poland, Portugal, QwaQwa, Romania, Russia, Scotland, Singapore, Slovakia, South Africa, Spain, Swaziland, Sweden, Switzerland, Taiwan, Tajikistan, Tonga, Transkei, Turkey, Ukraine, United Arab Emirates, United States of America, Uruguay, Uzbekistan, Wales, Zambia, Zimbabwe</p>\n\n<hr>\n',
#  nan,
#  nan,
#  nan,
#  '<p>Hello.</p>\n',
#  '<p>-</p>\n',
#  nan,
#  '<p>I occasionally say mildly funny things to people who know me well-enough.</p>\n',
#  '<p>/(bb|[^b]{2})/</p>\n',
#  '<p>I am a political science student at Haverford College, an amateur cook (http://181c.wordpress.com), an enthusiastic traveler (http://hostelhopping.wordpress.com), and an unexpected techie.</p>\n',
#  '<p>An internet addict interested in everything web and mobile. #SOreadytohelp</p>\n\n<p>Passionate about REST, APIs, MVC frameworks (client and server), user experience.</p>\n\n<p>A guitarist. A snowboarder. A tennis newbie. A traveler. An all-around nice guy.</p>\n\n<p>I am currently working for <a href="http://www.zopa.com" rel="nofollow">Zopa</a> as a senior developer.</p>\n\n<p>Blogging at <a href="http://www.slavoingilizov.com" rel="nofollow">http://www.slavoingilizov.com</a></p>\n',
#  nan,
#  '<p>Like going on journeys rather than jumping on a plane to a resort staying in the same place for a week and then getting the plane back.</p>\n',
#  '<p>Software Engineer in London, United Kingdom. Technologies of choice are Java, Hibernate, Spring, Ruby, Rails.</p>\n',
#  '<p>No risk - no fun.</p>\n',
#  nan,
#  nan,
#  nan,
#  '<p>Tech noobie. Travel addict, foodie, car enthusiast, Kannadiga, Manfriday, Leo.</p>\n',
#  "<p>I'm a software developer from the UK. \nI love to travel, I prefer city breaks and unusual destinations. Last year I spent a week in North Korea.</p>\n\n<p>I plan on doing the Mongol rally in the next few years</p>\n",
#  '<p><a href="http://about.me/akshayb" rel="nofollow">About Me</a></p>\n',
#  '<p>If you like StackOverflow favorites and wish improvements read my <strong><a href="http://meta.stackexchange.com/questions/75944/favorites-improvements">meta post</a></strong> and vote up.</p>\n',
#  '<p>Web developer, business analyst, project manager, and proud father.</p>\n\n<p><a href="http://stackexchange.com/users/23304161698f4515bc5398f3d3caf3a4">\n<img src="http://stackexchange.com/users/flair/23304161698f4515bc5398f3d3caf3a4.png" width="208" height="58" alt="profile for Beofett on Stack Exchange, a network of free, community-driven Q&amp;A sites" title="profile for Beofett on Stack Exchange, a network of free, community-driven Q&amp;A sites">\n</a></p>\n',
#  nan,
#  '<p><code>#SOreadytohelp</code></p>\n\n<p>I\'m George and I\'m a <a href="http://moviepilot.com" rel="nofollow">Web Developer</a>,\na sweet <a href="http://www.flickr.com/photos/nuc/4685521273/" rel="nofollow">dad</a>, a music <a href="http://www.last.fm/user/spacedive" rel="nofollow">passionate</a>, a decent <a href="http://cl.ly/30gL" rel="nofollow">cook</a>,\nan osx <a href="http://apple.stackexchange.com/users/1475/nuc">geek</a>, a board game <a href="http://boardgamegeek.com/user/nuchosya" rel="nofollow">lover</a>...</p>\n',
#  '<p>Officially voted <a href="https://twitter.com/df07/status/504677877544390656" rel="nofollow">World\'s Okayest Boss</a> by a plurality of coworkers in 2014.</p>\n\n<p>Formerly:</p>\n\n<ul>\n<li>New York (Careers &amp; Area 51) lead.</li>\n<li>Stack Exchange 1.0 dev lead.</li>\n<li><a href="http://www.fogcreek.com/" rel="nofollow">Fog Creek Software</a> developer and <a href="http://www.fogcreek.com/jobs/summerintern/" rel="nofollow">intern</a></li>\n</ul>\n\n<p>Check out my <a href="http://careers.stackoverflow.com/dfullerton">Stack Overflow Careers profile</a>!</p>\n',
#  '<p><a href="http://blog.stackoverflow.com/2010/04/welcome-stack-overflow-valued-associate-00005/">Stack Exchange Valued Associate #00005</a></p>\n\n<p>I am the Director of Community Development for the Stack Exchange Network.</p>\n\n<p>I can be reached at<br>\n<b>&#114;&#99;&#97;&#114;&#116;&#97;&#105;&#110;&#111;&#64;&#115;&#116;&#97;&#99;&#107;&#101;&#120;&#99;&#104;&#97;&#110;&#103;&#101;&#46;&#99;&#111;&#109;</b></p>\n',
#  '<p><a href="http://www.cs.drexel.edu/~eas28/" rel="nofollow">Computer Scientist</a>. <a href="http://www.sultanik.com/Blog:Ride_to_Reston" rel="nofollow">Cyclist</a>. <a href="http://cooking.stackexchange.com/users/5600/esultanik">Gastronomist</a>. <a href="http://tex.stackexchange.com/users/737/esultanik">Typographist</a>. <a href="http://mathoverflow.net/users/3951/esultanik" rel="nofollow">Mathemat</a>ic<a href="http://math.stackexchange.com/users/5022/esultanik">ist</a>.</p>\n\n<p><a href="http://stackexchange.com/users/62e7fe350a3444f593f35222257a9fea">\n<img src="http://stackexchange.com/users/flair/62e7fe350a3444f593f35222257a9fea.png" width="208" height="58" alt="profile for ESultanik on Stack Exchange, a network of free, community-driven Q&amp;A sites" title="profile for ESultanik on Stack Exchange, a network of free, community-driven Q&amp;A sites">\n</a></p>\n',
#  nan,
#  "<p>I'm a JS and .NET web apps developer from New England and now living near Washington, D.C. </p>\n\n<p>On a given day, you might catch me in either of those places. On a <em>good</em> day, I'll be somewhere with palm trees.</p>\n\n<p>These are a few of my favorite things:</p>\n\n<ul>\n<li>Service-oriented architecture</li>\n<li>JavaScript</li>\n<li>The MEAN stack</li>\n<li>ASP.NET MVC</li>\n<li>Skiing</li>\n</ul>\n",
#  '<p>I design stuff for Stack Exchange. Also a professional bacon eater.</p>\n\n<p>blog: <a href="http://www.8164.org" rel="nofollow">8164.org</a></p>\n\n<p>twitter: <a href="http://twitter.com/jzy" rel="nofollow">@jzy</a></p>\n',
#  nan,
#  nan,
#  '<p>I like: Ruby on Rails, Mobile Apps, IT/Strategy, Travel, etc. etc.</p>\n',
#  nan,
#  '<p>Co-founder: <a href="http://www.discourse.org" rel="nofollow">http://www.discourse.org</a> </p>\n\n<p>email: sam.saffron@gmail.com<br>\nblog: <a href="http://samsaffron.com" rel="nofollow">http://samsaffron.com</a><br>\ntwitter: <a href="https://twitter.com/@samsaffron" rel="nofollow">@samsaffron</a>   </p>\n\n<p>Ex <a href="http://blog.stackoverflow.com/2010/06/welcome-stack-overflow-valued-associate-00008/">Stack Overflow Valued Associate #00008</a>, creator of <a href="http://data.stackexchange.com/" rel="nofollow">Stack Exchange Data Explorer</a>, co-creator of Media Browser ( now emby <a href="http://emby.media/" rel="nofollow">http://emby.media/</a> ) </p>\n\n<p>Other Projects:</p>\n\n<ul>\n<li>Logster : <a href="https://github.com/discourse/logster" rel="nofollow">https://github.com/discourse/logster</a></li>\n<li>rack-mini-profiler : <a href="https://github.com/MiniProfiler/rack-mini-profiler" rel="nofollow">https://github.com/MiniProfiler/rack-mini-profiler</a></li>\n<li>message_bus : <a href="https://github.com/SamSaffron/message_bus" rel="nofollow">https://github.com/SamSaffron/message_bus</a></li>\n<li>memory_profiler: <a href="https://github.com/SamSaffron/memory_profiler" rel="nofollow">https://github.com/SamSaffron/memory_profiler</a></li>\n<li>flamegraph : <a href="https://github.com/SamSaffron/flamegraph" rel="nofollow">https://github.com/SamSaffron/flamegraph</a></li>\n</ul>\n\n<p>\nAll original source snippets I post on Stack Overflow are dedicated to the <a href="http://en.wikipedia.org/wiki/Public_Domain" rel="nofollow">public domain</a>. Do with them as you see fit. \n</p>\n',
#  '<p>em.\\?*.s@t</p>\n',
#  "<p>Backpacking since Christmas Day, 1989. Hitchhiking since mid 2010.</p>\n\n<p>For the first time I managed to save enough travel funds in less than six months in Australia.</p>\n\n<p>I've been hitchhiking around Malaysia, Thailand, Laos, Cambodia, Vietnam, and China; and will continue hitchhiking around Asia for the next two or so months. But will I make it all the way to Europe? ...</p>\n",
#  'me',
#  '<p>@chrisjlee</p>\n',
#  '<p>My websites: <br>\n<a href="http://www.SoftwareQuotes.com" rel="nofollow">Programming Quotes</a><br>\n<a href="http://www.PhotoQuotes.com" rel="nofollow">Photography Tips and Quotes</a>\n<br>\n<a href="http://www.Imageree.com" rel="nofollow">Stock Photography</a><br>\n<a href="http://www.Imagefree.com" rel="nofollow">Free images</a><br>\n<a href="http://www.IThinkOutsideTheBox.com" rel="nofollow">I think outside the box</a><br>\n<a href="http://www.Tilvitnun.is" rel="nofollow">Icelandic Quotes</a><br>\n<a href="http://www.MyFreeOCR.com" rel="nofollow">Free Online OCR</a><br>\n<a href="http://www.QuotesFromTwitter.com" rel="nofollow">Quotes from Twitter</a><br>\n<a href="https://www.MyTweetAlerts.com" rel="nofollow">Google Alerts for Twitter</a><br></p>\n',
#  'Geek, Gamer, Husband, Father',
#  nan,
#  nan,
#  nan,
#  '<p>I work at <a href="http://www.genexus.com" rel="nofollow">GeneXus</a>, a cross-platform, knowledge representation-based, development tool. I\'m part of the R&amp;D team, working with web generators.</p>\n',
#  "<p>I'm a software developer, used to work for telecom and Web. Started career at 2002. My key competences are Java and \xd0\xa1++ server programming. Another competence is Linux server administration. Also trying myself in client Web programming with JavaScript.</p>\n",
#  nan,
#  '<p>Developer at Telerik working on a code analysis and refactoring tool </p>\n\n<ul>\n<li>Twitter - <a href="http://twitter.com/s_angelov" rel="nofollow">http://twitter.com/s_angelov</a></li>\n</ul>\n',
#  "<p>I'm a polymath into engineering, software design, simulation, search and rescue, building things, cooking....</p>\n",
#  nan,
#  "\n\n<p>I use Apple hardware and Mac OS X since the age of dawn but work doing Android development using <s>Eclipse</s> Intellij-IDEA. Used to be a .NET/C# guy.<br /></p>\n\n<p>I do some Objective-C when time permits (never lately) and always experiment in Xcode when it's not crashing.</p>\n\n<p>Contrary to popular belief, I am <strong>not</strong> The Crow like my picture might suggest :)</p>\n\n<p>I have lived in the sunny Spain near Madrid for over eleven years, but now I live in San Francisco, CA. </p>\n\n<p>I'm currently working for 8tracks.com where I do mobile development. </p>\n",
#  "I'm a programmer since 1993, used to program in C, recently switched to javascript, after a lot of server side scripting in Php.\r\n\r\n",
#  '<p>I studied nuclear engineering primarily in my education, but I also indulged in many tangents such as electric power systems and Japanese. After doing lots of simulation work, I decided I would eventually be mainly a developer and that\'s what I\'m working on now.</p>\n\n<p>My hobbyist interest are many.  I like the maker movement, I\'m most interested in the sensors and data, the "internet of things" kind of stuff.  In physics, I\'m probably the most curious about general relativity topics. I\'ve been known to write about climate science when I feel like it. We once had a Nuclear Engineering proposal on Area 51, but it failed.</p>\n',
#  "<p>I'm a .Net programmer working in London, originally from New Zealand.</p>\n",
#  '<p><sup><a href="http://web.archive.org/web/20080514205739/http://www.math.wustl.edu/~msh210/legal.html#sm" rel="nofollow"><em>msh210</em> is a service mark.</a></sup></p>\n\n<hr>\n\n<p><a href="//meta.stackexchange.com/q/59445" rel="nofollow">useful to me and not so easy to find without this direct link</a></p>\n',
#  '<p>I code ruby</p>\n',
#  nan,
#  '<p>Denny Cherry is the owner and principal consultant for Denny Cherry &amp; Associates Consulting and has over a decade of experience working with platforms such as Microsoft SQL Server, Hyper-V, vSphere and Enterprise Storage solutions. Denny\xe2\x80\x99s areas of technical expertise include system architecture, performance tuning, security, replication and troubleshooting. Denny currently holds several of the Microsoft Certifications related to SQL Server for versions 2000 through 2008 including the Microsoft Certified Master as well as being a Microsoft MVP for several years.  Denny has written several books and dozens of technical articles on SQL Server management and how SQL Server integrates with various other technologies.\n<p>\nYou can find more information about Denny and Denny Cherry &amp; Associates Consulting at <a href="http://dcac.co" rel="nofollow">dcac.co</a> and more information about Denny\'s book Securing SQL Server on it\'s site <a href="http://securingsqlserver.com" rel="nofollow">securingsqlserver.com</a>.</p>\n',
#  nan,
#  '<p>Electrical engineering researcher</p>\n\n<ul>\n<li><a href="https://github.com/stevenblair" rel="nofollow">GitHub</a></li>\n<li><a href="http://personal.strath.ac.uk/steven.m.blair/" rel="nofollow">University homepage</a></li>\n<li><a href="http://blog.superuser.com/author/sblair/" rel="nofollow">Super User blog entries</a></li>\n</ul>\n\n\n',
#  '<p>My first computer (1983) was a Commodore VIC-20:\n<br /><br />\n<img src="http://img124.imageshack.us/img124/9937/vic20of3.png" alt="3583 bytes free." />\n<br />\n<br />I love my wife, my two kids &amp; my job as developer. I\'m a PC, but I own some Macs and iStuff too.</p>\n',
#  '3n32fgcl98cZ92u4',
#  nan,
#  nan,
#  '<p>Engineering smart giving products for churches at <a href="http://kindrid.com" rel="nofollow">Kindrid</a>. Previously co-founder of <a href="https://applyance.com" rel="nofollow">Applyance</a> and <a href="https://hackapp.co" rel="nofollow">hack_app</a>.</p>\n\n<ul>\n<li>HTML5, CSS3</li>\n<li>JavaScript, Backbone, Angular</li>\n<li>Ruby, Ruby on Rails, Sinatra</li>\n<li>NodeJS, Express, Meteor</li>\n<li>PHP, WordPress</li>\n<li>C#, ASP.NET, MVC</li>\n<li>Java</li>\n</ul>\n',
#  '<p><a href="http://careers.stackoverflow.com/caderoux">Stack Overflow CV</a></p>\n',
#  '<p>Shawn Wildermuth is a ten-time Microsoft MVP (ASP.NET/IIS) and is involved with Microsoft as a Data Insider and ASP.NET Insider. You may have taken one of his many courses on Pluralsight including \xe2\x80\x9cJavaScript for C# Developers\xe2\x80\x9d or \xe2\x80\x9cA Better CSS: LESS and SASS\xe2\x80\x9d. He is also the author of eight books and dozens of articles on software development. He has been seen speaking at a variety of international conferences including TechEd, Oredev, SDC, VSLive, WinDev, MIX, DevTeach, DevConnections and DevReach. He is one of the Wilder Minds at <a href="http://wilderminds.com" rel="nofollow">http://wilderminds.com</a>.  He can also be reached via his blog at <a href="http://wildermuth.com" rel="nofollow">http://wildermuth.com</a>.</p>\n',
#  'Here to learn and share.',
#  nan,
#  nan,
#  '<p>Landscape photog, dad, SmugSourcerer.</p>\n',
#  '<p><a href="http://careers.stackoverflow.com/amrelgarhy">http://careers.stackoverflow.com/amrelgarhy</a></p>\n',
#  '<p>software engineer working on web and mobile</p>\n',
#  nan,
#  nan,
#  nan,
#  "<p>I'm a developer from Takoma Park, MD.</p>\n\n<p>At the office, I work on MSSQL, C#, VB.NET, Javascript, ASP.NET.</p>\n\n<p>At home, I'm a vegan, a sci-fi fan, dabble in foreign languages and enjoy book clubs.</p>\n\n<p>I will try to up vote everyone who answers me and I thank everyone who has freely given me some of their time to answer my various questions.</p>\n",
#  nan,
#  '<p>I am a moderator on Super User and Fitness.SE. \n<br/><br/>\nI work on medical image processing at <a href="https://www.clinicalgraphics.com" rel="nofollow">Clinical Graphics</a>.\n<br/><br/>\nYou can follow me on Twitter: <a href="http://twitter.com/#!/ivoflipse5" rel="nofollow">ivoflipse5</a></p>\n\n<p><a href="http://stackoverflow.com/users/77595/ivo-flipse">\n<img src="http://stackoverflow.com/users/flair/77595.png" width="208" height="58" alt="profile for Ivo Flipse at Stack Overflow, Q&amp;A for professional and enthusiast programmers" title="profile for Ivo Flipse at Stack Overflow, Q&amp;A for professional and enthusiast programmers">\n</a></p>\n',
#  '<p>Eric Bowen is a former Microsoft Architect Evangelist and currently an Independent Software Developer focused on developing Microsoft Silverlight and ASP.NET MVC applications on the Amazon and Microsoft cloud platforms (Azure, EC2, S3, SQS, SimpleDB, DynamoDB, RDS, Elastic Beanstalk, etc...) <br><br></p>\n\n<p>Eric has been programming for 28 years since he taught himself Z80 assembly language on his family\'s TRS-80 Model I Level II.  And he has still never worn the t-shirt that Bill Gates signed when he won the programming contest at the Microsoft PDC in 2001.</p>\n\n<p><a href="http://twitter.com/#!/scrappydog" rel="nofollow" title="Twitter">Twitter</a></p>\n',
#  nan,
#  '<p>I really enjoy making things in a few different ways: I like to code, make beer, make music, write poetry, draw things, and more. </p>\n\n<h1>SOreadytohelp.</h1>\n',
#  nan,
#  nan,
# ...
#  "<p>I'm bored a lot of the time and willing to help people for free.</p>\n\n<p>If you need help, or want a clarification on a question I've answered or commented on, please google talk me at carter.barry@gmail.com ... of course, you can also use SE's own comment/answer features or email me, but google talk is fastest.</p>\n\n<p>You can also google talk me if you have a math/science question unrelated to SE.</p>\n",
#  '<p>Rob Windsor is a Lead SharePoint Consultant with Allin Consulting based in Boston. He has over seventeen years experience developing rich-client and web applications with Delphi, VB, C# and VB.NET and is currently spending a majority of his time working with SharePoint. Rob is a regular speaker at conferences, code camps, and user groups across North America and Europe. He regularly contributes articles and videos to MSDN, TechNet, and the Pluralsight On-Demand library and is the co-author of Professional Visual Basic 2010 and .NET for Wrox. Rob is the founder and part-president of the Toronto Visual Basic User Group and has been recognized as a Microsoft Most Valuable Professional for his involvement in the developer community. </p>\n<p><a href="http://twitter.com/robwindsor">@robwindsor</a></p>',
#  nan,
#  '<p>Proclamares saltem suppetiatum, si resistere vir tantus mulieri nequibas. Sub oculis tuis homo iugulatur, et siles? Cur autem te simile latrocinium non peremit? Cur saeva crudelitas vel propter indicium sceleris arbitro pepercit?</p>\n\n<p><a href="http://area51.stackexchange.com/proposals/11942/game-of-go?referrer=HmgCGKA1KBq37ioaqR_AEA2">http://area51.stackexchange.com/proposals/11942/game-of-go?referrer=HmgCGKA1KBq37ioaqR_AEA2</a></p>\n',
#  nan,
#  '<p>Studies Astrophysics @ Sofia University, Bulgaria</p>\n',
#  '<p>I\'m a web developer for <a href="http://findaccountingsoftware.com/" rel="nofollow">Find Accounting Software</a>.</p>\n',
#  '<p>Vagabond IT consultant and freelance writer.</p>\n',
#  '<p>I\'m sysadmin and software developer with more than a decade of experience (see\n<a href="http://careers.stackoverflow.com/alexeydemidov">CV</a> for details).</p>\n',
#  '<p>I\xe2\x80\x99m Artur Rodrigues, and I\xe2\x80\x99m a software engineer at <a href="http://www.idxpanalytics.com/" rel="nofollow">IDXP Analytics</a> where I capture probe requests on OpenWRT powered routers, build big data algorithms using scientific packages in Python, develop RESTful APIs with Rails and PostgreSQL and handle all of the DevOps efforts involved in collecting millions of data points every week.</p>\n\n<p>I\'ve also recently dropped out from a CS Masters degree in Data Visualization. During this academic period, I created two big visualization projects: <a href="https://github.com/arturhoo/como-nos-sentimos" rel="nofollow">Como nos Sentimos</a> and <a href="http://www.artur-rodrigues.com/ADVISe/" rel="nofollow">ADVISe</a>.</p>\n\n<p>Before joining IDXP, I\'ve spent two years at <a href="http://www.elogroup.com.br" rel="nofollow">EloGroup</a> as a Rails developer and DevOps engineer, taking care of 100+ AWS and on-premises servers, ensuring that they were <a href="https://www.github.com/innvent/parcelles" rel="nofollow">consistently provisioned</a> and applications were <a href="https://www.github.com/innvent/matross" rel="nofollow">properly deployed</a> and <a href="https://www.github.com/arturhoo/sns-twilio" rel="nofollow">monitored</a>. I\'ve also worked at <a href="http://deskmetrics.com" rel="nofollow">DeskMetrics</a> and <a href="http://www.cemig.com.br" rel="nofollow">CEMIG</a>, and was a visiting CS student at <a href="http://www.leeds.ac.uk" rel="nofollow">University of Leeds</a>.</p>\n\n<p>When I am not coding, I get inspired by seeing creative visualizations and large interactive installations. In the last year, I\'ve also become highly interested in investing and how people deal with money in general. I like to think I\'m a great <a href="http://www.artur-rodrigues.com/img/karting.jpg" rel="nofollow">Go-kart driver</a>, an <a href="http://www.artur-rodrigues.com/img/swimming.jpg" rel="nofollow">ok swimmer</a>, and insist that every Brazilian (and pretty much everyone that can afford it) should visit <a href="http://www.inhotim.org.br" rel="nofollow">Inhotim</a>.</p>\n',
#  'developer',
#  '<p>I am master student studying AI. At the very beginning of my course.</p>\n',
#  '<p>Software Developer. Obsessive Compulsive code formatter and documenter. Tabs-over-spaces preferrer but that doesn\xe2\x80\x99t always work out. Server Administrator. Arch Linux user (but not on servers).</p>\n',
#  '<p>Ruby, Javascript, Clojure developer.</p>\n\n<p>Personal site: <a href="http://leonid.shevtsov.me" rel="nofollow">http://leonid.shevtsov.me</a></p>\n\n<p>Github: <a href="https://github.com/leonid-shevtsov" rel="nofollow">https://github.com/leonid-shevtsov</a></p>\n\n<h1>SOreadytohelp</h1>\n',
#  '<p>bean in the Java world</p>\n',
#  nan,
#  "Unix / Linux admin, now focused on grid computing and networking.  I've recently converted from perl to python for basic scripting and admin tasks, and am still learning every day.  Very interested in the django framework for a new side-project, which precipitated the move to python.",
#  nan,
#  nan,
#  nan,
#  '<p>I<br />\n\xe2\x80\xa6 am a freelancing IT-consultant<br />\n\xe2\x80\xa6 call my self a software developer<br />\n\xe2\x80\xa6 have been in the business since 1996<br />\n\xe2\x80\xa6 like to design databases<br />\n\xe2\x80\xa6 don\xe2\x80\x99t like to design user interfaces<br />\n\xe2\x80\xa6 enjoy solving problems<br /></p>\n',
#  nan,
#  nan,
#  nan,
#  nan,
#  '<p>IT Program and Project Manager for more that 10 years. Involved in e-Health and Telemedicine projects requirements gathering and management since 2005.</p>\n',
#  nan,
#  '<p>Dealing with the abstract.</p>\n',
#  nan,
#  '<p>I teach probability and statistics at the University of Alberta.</p>\n',
#  nan,
#  '<p>Web Development Explorer</p>\n\n<p>FB: <a href="http://www.facebook.com/yoyon.cahyono" rel="nofollow">http://www.facebook.com/yoyon.cahyono</a></p>\n\n<p>Twitter: <a href="http://twitter.com/gajahlemu" rel="nofollow">http://twitter.com/gajahlemu</a></p>\n',
#  '<p>\xc2\xab"Five to one against and falling..." she said, "four to one against and falling...three to one...two...one...probability factor of one to one...we have normality, I repeat we have normality." She turned her microphone off \xe2\x80\x94 then turned it back on, with a slight smile and continued: "Anything you still can\xe2\x80\x99t cope with is therefore your own problem."\xc2\xbb</p>\n\n<p>\xe2\x80\x9c[\xe2\x80\xa6] If I revisited that decision today, I might even go so far as to remove single inheritance as well. Inheritance just isn\xe2\x80\x99t all that important. Encapsulation is OOP\xe2\x80\x99s lasting contribution.\xe2\x80\x9d \xe2\x80\x94 Brad Cox was asked, why Objective-C doesn\xe2\x80\x99t have multiple inheritance.(Masterminds of Programming: Conversations with the Creators of Major Programming Languages, p. 259)</p>\n\n<hr>\n\n<h3>Enlightening</h3>\n\n<ul>\n<li><a href="http://me.veekun.com/blog/2012/04/09/php-a-fractal-of-bad-design/" rel="nofollow">A fractal of bad design</a></li>\n<li><a href="http://mattgemmell.com/2012/05/24/api-design/" rel="nofollow">API Design</a></li>\n<li><a href="http://rixstep.com/2/2/20100709,00.shtml" rel="nofollow">Objective-C, Objectively</a></li>\n</ul>\n',
#  '<p>Some high voted answers:<br/>\n<a href="http://stackoverflow.com/questions/5024056/how-to-pass-parameters-on-onchange-of-html-select/5024082#5024082">How to pass parameters on onChange of html select</a> <br/>\n<a href="http://stackoverflow.com/questions/5367164/remove-substring-from-the-string/5367181#5367181">Remove substring from the string</a> <br/>\n<a href="http://stackoverflow.com/questions/5616898/java-sql-sqlexception-no-suitable-driver-found-for-jdbcmicrosoftsqlserver/5617164#5617164">java.sql.SQLException: No suitable driver found for jdbc:microsoft:sqlserver</a><br/>\n<a href="http://stackoverflow.com/questions/5521224/difference-between-plugins-and-ruby-gems/5521244#5521244">Difference between plugins and Ruby gems?</a><br/>\n<a href="http://stackoverflow.com/questions/4905416/adding-one-month-to-current-date/4905433#4905433">Adding one month to current date?</a><br/>\nOn StackOverflow - focusing on : <br/> \n<code>Back End</code>: Core/Enterprise Java (Concurrency, Collections), Ruby, Advanced SQL, Hibernate, Spring(AOP, ORM, IOC, MVC, Security, Enterprise Services), Node.js, Redis, Stored Procedures, Load Balancing, Failover, Clustering, Relational/ No SQL databases.<br/> \n<code>Android Mobile Platform</code>: <a href="https://groups.google.com/forum/?fromgroups#!forum/android_learning" rel="nofollow">Android SDK Group</a> <br/>\n<code>Functional Programming</code>: Groovy <br/>\n<code>SOA</code>: Web Services (SOAP/REST), Spring REST and related stuff<br/>\n<code>Front End</code>: Java FX, Java Web-Mobile Components, MVC (Spring, Struts), Ajax, Angular.js, HTML5, Native JavaScript, JFreeChart, RIA, Jquery, CSS, JSON, JSTL, Tag Libraries.<br/>\n<code>Networking</code>,<code>Administration</code>: Linux Kernel Services/Configuration, Linux Filesystem/Package/Account Management, TCP/IP, NFS, Clustering, Opsview.<br/>\n<code>Big Data</code>: Hadoop, MapReduce, HDFS, Pig, Hive, ZooKeeper, Sqoop <br/>\n<code>DevOps</code>: Chef, Puppet, Ansible, ElasticSearch, Logstash, Kibana <br/>\n<code>Data Science</code>: R, Github <br/>\n<code>Cloud</code>: AWS, SaaS, PaaS,DBaaS, Docker, RedHat OpenShift <br/>\n<code>No SQL</code>: Document-Oriented (MongoDb), HBase, Column Oriented (Cassandra) <br/>\n<code>Algorithms</code>: Divide &amp; Conquer, Graphs, Data structures(Heaps, Hash tables, Search trees), Randomized algorithms <br/>\n<code>Scripting</code>: Bash, Shell, Excel VBA.<br/>\n<code>Search Engine Technology</code>: Lucene <br/>\n<code>Project Management</code>: Agile, Scrum.<br/>\n<code>OS</code>: Ubuntu, Linux, Solaris, Windows.<br/>\n<code>SCM</code>: Configuration Management(Maven ,Ant), Continuous Integration.<br/></p>\n',
#  '<p>Co-founder and CEO of Cactusoft where we specialize in the development of custom, process-oriented software. We work with local SMEs, looking to provide software solutions that emphasize their competitive advantage.</p>\n\n<p>I also double as a full-stack C# Web developer.</p>\n\n<p>My blog: <a href="http://bryblog.com" rel="nofollow">bryblog</a></p>\n',
#  nan,
#  '<p><a href="https://twitter.com/Stephen_Batty" rel="nofollow">Infrequent tweets</a></p>\n\n<p><a href="https://archive.rebeccablacktech.com/g/thread/43324376" rel="nofollow">What if programming languages were methods to eat an orange?</a></p>\n\n<p><a href="http://centraldish.com/" rel="nofollow">Live in London,and want help finding a meal ?</a></p>\n',
#  nan,
#  '<p>end-to-end full-stack web developer</p>\n',
#  nan,
#  '<p>I\'m a senior developer at <a href="http://intelligentvoice.com" rel="nofollow">Intelligent Voice</a> in London.  We build great software for the financial services industry.</p>\n',
#  '<h2>Being relatively anonymous allows me to submit the stupid questions that other people are too afraid to ask.</h2>',
#  '<p>Pravin Started programming with C/C++, then moved into .NET technology. He wrote his first .NET application using VS2003 (.NET 1.1). Has worked in VS2005, VS2008, VS2010 since then.</p>\n\n<p>Pravin specializes in Windows, Web, Distributed Systems Development with emphasis on Design Patterns and Software Architecture. He has developed many websites - <a href="http://www.exploremyschool.com" rel="nofollow">Explore My School</a> being the latest.</p>\n\n<p>Pravin is born and brought up in Nasik, India. He has completed BE Computer and now doing MS in Software Systems. He has achieved MCP, MCTS and MCPD certifications from microsoft. He writes technology articles at his blog - <a href="http://www.techmyview.com/" rel="nofollow">TechMyView</a>. He is a very active contributer to online forums - <a href="http://www.codeproject.com/script/Membership/View.aspx?mid=6577363" rel="nofollow">Codeproject</a>, <a href="http://stackoverflow.com/users/855651/pravin-patil">Stack Overflow</a>, <a href="http://programmers.stackexchange.com/users/38347/pravin-patil">Programmers</a>, <a href="http://codegolf.stackexchange.com/users/2935/pravin-patil">Code Golf</a>, <a href="http://codereview.stackexchange.com/users/7604/pravin-patil">Code Review</a>, <a href="http://social.msdn.microsoft.com/Profile/patil%20pravin" rel="nofollow">Microsoft Forums</a>.</p>\n\n<p>Other than Technical stuff Pravin is very much passionate about music. He plays Guitar and Mouth Organ. Visit his profile at <a href="http://www.indianguitartabs.com/member148736.html%22%20target=%22_blank" rel="nofollow">Indian Guitar Tabs</a>, <a href="http://meta.music.stackexchange.com/users/1357/pravin-patil">Music Stackexchange</a>. He is also an avid reader. He likes to complete at least one book per week. He writes the book reviews at his blog <a href="http://bookreviews.techmyview.com/" rel="nofollow">Book Reviews - An Avocation Recapitulated as Blog</a>.</p>\n',
#  "I'm everywhere",
#  '<p>I am a web designer and developer. I specialize in creating high quality content. <a href="http://dpend.design" rel="nofollow">http://dpend.design</a></p>\n',
#  nan,
#  '<p>Developer focus solving problems.</p>\n',
#  '<p></p>\n\n<h1>SOreadytohelp</h1>\n',
#  nan,
#  nan,
#  '<p>Object.const_set("Love", Class.new { def ruby() true end });i = Love.new;i.ruby</p>\n',
#  nan,
#  '<p>Programmer</p>\n',
#  nan,
#  nan,
#  "I'm a Delphi and C# developer by trade specialising in energy management software. Outside of work I like to tinker with Apple hardware.",
#  '<p><a href="http://www.antonytrupe.com/p/husband" rel="nofollow">husband</a>, <a href="http://www.antonytrupe.com/p/father" rel="nofollow">father</a>, <a href="http://www.antonytrupe.com/p/developer" rel="nofollow">developer</a>, <a href="http://www.antonytrupe.com/p/tester" rel="nofollow">tester</a>, <a href="http://www.antonytrupe.com/p/maker" rel="nofollow">maker</a>, <a href="http://www.antonytrupe.com/p/employee" rel="nofollow">business process analyst</a>, <a href="http://www.antonytrupe.com/p/american" rel="nofollow">usa citizen</a>, <a href="http://www.antonytrupe.com/p/human" rel="nofollow">human</a></p>\n',
#  "<p>I'm a robot, but you've probably never heard of me.</p>\n",
#  nan,
#  nan,
#  nan,
#  nan,
#  '<p>Software Developer at a large international IT corporation, working on databases and programming languages, sometimes digging into other things. Can often be found riding one of his bikes.</p>\n',
#  nan,
#  "<p>I'm a web technologies enthusiast. More than buzz words, I LOVE the idea of making things for people to use. There's something incredible about thinking as a user and making apps that are user friendly and intuitive to use. The web platform just allows me to reach the most people at once.</p>\n",
#  nan,
#  nan,
#  nan,
#  '<h1>SOreadytohelp</h1>\n\n<p>Below is the current open source projects I work on.<br />\nA tool to manage Stored Procedures, Triggers, Views and get autocompletion:<br />\n<a href="https://github.com/itay-moav/rahl_commander" rel="nofollow">https://github.com/itay-moav/rahl_commander</a><br />\n<br />\nA fun way to point users at the right direction in your site ;-)<br />\n<a href="https://github.com/itay-moav/babahandofgod" rel="nofollow">https://github.com/itay-moav/babahandofgod</a><br />\n<br />\nAn old version of WMD which I converted to Mootools, 4 years ago...<br />\n<a href="http://moowmd.awardspace.info" rel="nofollow">http://moowmd.awardspace.info</a> </p>\n\n<p>Feel free to contact me through linkedin <a href="http://www.linkedin.com/in/itaymoav" rel="nofollow">http://www.linkedin.com/in/itaymoav</a></p>\n',
#  nan,
#  nan,
#  nan,
#  nan,
#  ...]

# %%
badges.head()

# %%
votes_train.head()

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 2. What makes an answer likely to be "accepted"?
#
# ---
#
# **2.1 Build a model to predict whether a post will be marked as the answer.**
#
# - This is a classification problem.
# - You're free to use any of the machine learning algorithms or techniques we have learned in class to build the best model you can.
# - NLP will be very useful here for pulling out useful and relevant features from the data.
# - Though not required, using bagging and boosting models like Random Forests and Gradient Boosted Trees will _probably_ get you the highest performance on the test data (but who knows!).
#
#
# **2.2 Evaluate the performance of your classifier with a confusion matrix and accuracy. Explain how your model is performing.**
#
# **2.3 Plot either a ROC curve or precision-recall curve (or both!) and explain what they tell you about your model.**
#
# NOTE: You should only be predicting this for `PostTypeID=2` posts, which are the "answer" posts. This doesn't mean, however, that you can't or shouldn't use the parent questions as predictors!

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 3. What is the score of a post?
#
# ---
#
# **3.1 Build a model that predicts the score of a post.**
#
# - This is a regression problem now.
# - You can and should be predicting score for both "question" and "answer" posts, so keep them both in your dataset.
# - Again, use any techniques that you think will get you the best model.
#
# **3.2 Evaluate the performance of your model with cross-validation and report the results.**
#
# **3.3 What is important for determining the score of a post, if anything?**

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 4. How many views does a post have?
#
# ---
#
# **4.1 Build a model that predicts the number of views a post has.**
#
# - This is another regression problem.
# - Predict the views for all posts, not just the "answer" posts.
#
# **4.2 Evaluate the performance of your model with cross-validation and report the results.**
#
# **4.3 What is important for the number of views a post has, if anything?**

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 5. Build a pipeline or other code to automate evaluation of your models on the test data.
#
# ---
#
# Now that you've constructed your three predictive models, build a pipeline or code that can easily load up the raw testing data and evaluate your models on it.
#
# The testing data that is held out is in the same raw format as the training data you have. _Any cleaning and preprocessing that you did on the training data will need to be done on the testing data as well!_
#
# This is a good opportunity to practice building pipelines, but you're not required to. Custom functions and classes are fine as long as they are able to process and test the new data.
